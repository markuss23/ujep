# %% [markdown]
# # šum v signálu

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
freq = 5  # Frequency of the clean signal (Hz)
length = 1  # Duration of the signal (seconds)
num_points = 500  # Number of sample points
noise_std = 1  # Standard deviation of the noise
window_size = 10  # Window size for the moving average filter

# Generate a clean signal
t = np.linspace(0, length, num_points)
clean_signal = np.sin(2 * np.pi * freq * t)

# Add noise to the signal
noise = np.random.normal(0, noise_std, clean_signal.shape)
noisy_signal = clean_signal + noise

# Apply moving average filter for denoising (shadowing effect)
smoothed_signal = np.convolve(
    noisy_signal, np.ones(window_size) / window_size, mode="same"
)

# Plot the clean, noisy, and smoothed signals
plt.figure(figsize=(10, 5))
plt.plot(t, clean_signal, label="Clean Signal")
plt.plot(t, noisy_signal, label="Noisy Signal")
plt.plot(t, smoothed_signal, label="Denoised Signal (Shadowing)")
plt.legend()
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.title("Clean, Noisy, and Denoised Signal (Shadowing Effect)")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
length = 1                # Duration of the signal (seconds)
num_points = 500          # Number of sample points
noise_std = 1             # Standard deviation of the noise
window_size = 10          # Window size for the moving average filter

# Generate a linear signal
t = np.linspace(0, length, num_points)
linear_signal = 2 * t + 1  # Linear function (y = 2 * t + 1)

# Add noise to the linear signal
noise = np.random.normal(0, noise_std, linear_signal.shape)
noisy_linear_signal = linear_signal + noise

# Apply moving average filter for denoising (shadowing effect)
smoothed_linear_signal = np.convolve(noisy_linear_signal, np.ones(window_size) / window_size, mode='same')

# Plot the clean, noisy, and smoothed linear signals
plt.figure(figsize=(10, 5))
plt.plot(t, linear_signal, label='Clean Linear Signal')
plt.plot(t, noisy_linear_signal, label='Noisy Linear Signal')
plt.plot(t, smoothed_linear_signal, label='Denoised Linear Signal (Shadowing)')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Clean, Noisy, and Denoised Linear Signal (Shadowing Effect)')
plt.show()
